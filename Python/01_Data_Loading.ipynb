# %%
import pandas as pd
import numpy as np

# %%
forex_data = pd.read_csv("Data/forex_price_data.csv")

# %%
trade_log = pd.read_csv("Data/trade_log.csv")

# %%
mc_scenarios = pd.read_csv("Data/mc_scenarios.csv")

# %%
print("Forex Price Data Loaded Successfully")
print("Trade Log Loaded Successfully")
print("Monte Carlo Scenarios Loaded Successfully")
# Out:
# Forex Price Data Loaded Successfully
# Trade Log Loaded Successfully
# Monte Carlo Scenarios Loaded Successfully

# %%
print("Forex Price Data Shape:", forex_data.shape)
print("Trade Log Shape:", trade_log.shape)
print("Monte Carlo Shape:", mc_scenarios.shape)
# Out:
# Forex Price Data Shape: (500, 9)
# Trade Log Shape: (150, 15)
# Monte Carlo Shape: (1000, 8)

# %%
forex_data.head()
# Out:
#               DateTime  PairID PairName     Open     High      Low    Close  \
# 0  2023-01-01 00:00:00       1  EUR/USD  1.08103  1.08103  1.08019  1.08054
# 1  2023-01-01 01:00:00       1  EUR/USD  1.08010  1.08043  1.07974  1.08028
# 2  2023-01-01 02:00:00       1  EUR/USD  1.08036  1.08158  1.07961  1.08054
# 3  2023-01-01 03:00:00       1  EUR/USD  1.08068  1.08126  1.07973  1.08088
# 4  2023-01-01 04:00:00       1  EUR/USD  1.08042  1.08042  1.07967  1.08030
#
#    Volume  Spread
# 0    2651     0.9
# 1    2292     1.0
# 2    1796     1.2
# 3    4019     1.4
# 4    2207     1.6

# %%
trade_log.head()
# Out:
#    TradeID PairName StrategyName   SignalType Direction  EntryPrice  \
# 0        1  USD/JPY   MACD_Trend          BUY      LONG   154.16999
# 1        2  USD/INR     MA_Cross  STRONG_SELL     SHORT    83.90144
# 2        3  USD/JPY       RL_PPO          BUY      LONG   150.56125
# 3        4  GBP/USD        ML_RF         SELL     SHORT     1.23636
# 4        5  AUD/USD       RL_PPO          BUY      LONG     0.66810
#
#    ExitPrice EntryDateTime                   ExitDateTime  PositionSize  \
# 0  154.17229    2024-07-15  2024-07-17 23:45:36.000000000        100000
# 1   83.90070    2024-02-08  2024-02-10 11:45:36.000000000        100000
# 2  150.56093    2024-06-26  2024-06-28 10:19:12.000000000        100000
# 3    1.23434    2024-03-26  2024-03-28 14:24:00.000000000        100000
# 4    0.66700    2024-06-05  2024-06-06 11:02:24.000000000        100000
#
#       PnL  PnL_Pips  HoldingDays  Commission  IsOpen
# 0  2300.0      23.0         2.99         7.0   False
# ...

# %%
mc_scenarios.head()
# Out:
#    ScenarioID  ParallelShift  VolShock  CorrShock  EURUSD_PnL  USDJPY_PnL  \
# 0           1       0.007477  0.047435  -0.005085   -47135.91   -12006.44
# 1           2       0.009984 -0.015458  -0.022252   -67806.11   -23561.05
# 2           3       0.017714  0.024560   0.021290  -105268.35   -37015.49
# 3           4      -0.003975 -0.015789  -0.028162    31602.99     2908.07
# 4           5       0.020120  0.006809   0.003554  -118486.89   -46873.73
#
#    GBPUSD_PnL  PortfolioPnL
# 0   -16290.94     -75433.29
# 1   -19792.70    -111159.86
# 2   -30672.66    -172956.50
# 3     4799.50      39310.56
# 4   -37796.98    -203157.60

# %%
print("Forex Price Data Columns:")
print(forex_data.columns)

print("\nTrade Log Columns:")
print(trade_log.columns)

print("\nMonte Carlo Columns:")
print(mc_scenarios.columns)
# Out:
# Forex Price Data Columns:
# Index(['DateTime', 'PairID', 'PairName', 'Open', 'High', 'Low', 'Close',
#        'Volume', 'Spread'],
#       dtype='str')
#
# Trade Log Columns:
# Index(['TradeID', 'PairName', 'StrategyName', 'SignalType', 'Direction',
#        'EntryPrice', 'ExitPrice', 'EntryDateTime', 'ExitDateTime',
#        'PositionSize', 'PnL', 'PnL_Pips', 'HoldingDays', 'Commission',
#        'IsOpen'],
#       dtype='str')
#
# Monte Carlo Columns:
# Index(['ScenarioID', 'ParallelShift', 'VolShock', 'CorrShock', 'EURUSD_PnL',
#        'USDJPY_PnL', 'GBPUSD_PnL', 'PortfolioPnL'],
#       dtype='str')

# %%
print("Forex Price Data:")
forex_data.info()

print("\nTrade Log:")
trade_log.info()

print("\nMonte Carlo Scenarios:")
mc_scenarios.info()
# Out:
# Forex Price Data:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  500 non-null    str
#  1   PairID    500 non-null    int64
#  2   PairName  500 non-null    str
#  3   Open      500 non-null    float64
#  4   High      500 non-null    float64
#  5   Low       500 non-null    float64
#  6   Close     500 non-null    float64
#  7   Volume    500 non-null    int64
#  8   Spread    500 non-null    float64
# dtypes: float64(5), int64(2), str(2)
# memory usage: 35.3 KB
#
# Trade Log:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TradeID        150 non-null    int64
#  1   PairName       150 non-null    str
#  2   StrategyName   150 non-null    str
#  3   SignalType     150 non-null    str
# ...

# %%
forex_data.describe()
# Out:
#        PairID        Open        High         Low       Close        Volume  \
# count   500.0  500.000000  500.000000  500.000000  500.000000    500.000000
# mean      1.0    1.088002    1.088494    1.087540    1.088007   3368.230000
# std       0.0    0.015255    0.015222    0.015234    0.015236   1697.493162
# min       1.0    1.065410    1.065900    1.064320    1.065750    788.000000
# 25%       1.0    1.074313    1.074982    1.073948    1.074315   2173.000000
# 50%       1.0    1.083095    1.083570    1.082685    1.082990   2990.000000
# 75%       1.0    1.104668    1.104963    1.104078    1.104763   4056.750000
# max       1.0    1.118660    1.118660    1.117880    1.118130  13023.000000
#
#            Spread
# count  500.000000
# mean     1.405600
# std      0.358756
# min      0.800000
# 25%      1.100000
# 50%      1.400000
# 75%      1.700000
# max      2.000000

# %%
trade_log.describe()
# Out:
#           TradeID  EntryPrice   ExitPrice  PositionSize          PnL  \
# count  150.000000  150.000000  150.000000         150.0   150.000000
# mean    75.500000   41.894922   41.895088      100000.0    12.766667
# std     43.445368   58.152366   58.152166           0.0  1664.847964
# min      1.000000    0.643510    0.638620      100000.0 -6590.000000
# 25%     38.250000    1.059195    1.057743      100000.0  -288.750000
# 50%     75.500000    1.237020    1.237965      100000.0    70.000000
# 75%    112.750000   83.094157   83.094285      100000.0   345.250000
# max    150.000000  154.169990  154.172290      100000.0  6050.000000
#
#          PnL_Pips  HoldingDays  Commission
# count  150.000000   150.000000       150.0
# mean     2.806667     2.407333         7.0
# std     28.992708     1.373833         0.0
# min    -77.500000     0.120000         7.0
# 25%    -17.450000     1.297500         7.0
# 50%      5.000000     2.470000         7.0
# ...

# %%
mc_scenarios.describe()
# Out:
#         ScenarioID  ParallelShift     VolShock    CorrShock     EURUSD_PnL  \
# count  1000.000000    1000.000000  1000.000000  1000.000000    1000.000000
# mean    500.500000      -0.000256     0.001550    -0.000346    3832.546610
# std     288.819436       0.009875     0.049927     0.019751   64415.250771
# min       1.000000      -0.034258    -0.171268    -0.069338 -167387.970000
# 25%     250.750000      -0.007129    -0.032942    -0.014002  -42006.905000
# 50%     500.500000      -0.000009     0.000585     0.000677    1411.425000
# 75%     750.250000       0.006604     0.038021     0.012586   47599.975000
# max    1000.000000       0.028453     0.202628     0.055251  250415.550000
#
#          USDJPY_PnL    GBPUSD_PnL   PortfolioPnL
# count   1000.000000   1000.000000    1000.000000
# mean     626.876530    411.914080    4871.337220
# std    21062.977037  17439.181828  102545.653127
# min   -57943.130000 -47470.500000 -269801.360000
# ...
