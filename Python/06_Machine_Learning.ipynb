# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\Users\soumya sircilla\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\Users\soumya sircilla\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (2.4.6)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\soumya sircilla\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in c:\Users\soumya sircilla\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\soumya sircilla\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\Users\soumya sircilla\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
forex_data = pd.read_csv("Signal_Data/forex_with_signals.csv")

# %%
forex_data.head()
# Out:
#               DateTime  PairID PairName     Open     High      Low    Close  \
# 0  2023-01-01 00:00:00       1  EUR/USD  1.08103  1.08103  1.08019  1.08054
# 1  2023-01-01 01:00:00       1  EUR/USD  1.08010  1.08043  1.07974  1.08028
# 2  2023-01-01 02:00:00       1  EUR/USD  1.08036  1.08158  1.07961  1.08054
# 3  2023-01-01 03:00:00       1  EUR/USD  1.08068  1.08126  1.07973  1.08088
# 4  2023-01-01 04:00:00       1  EUR/USD  1.08042  1.08042  1.07967  1.08030
#
#    Volume  Spread  SMA_10  SMA_20    EMA_10  RSI      MACD  Signal_Line  \
# 0    2651     0.9     NaN     NaN  1.080540  NaN  0.000000     0.000000
# 1    2292     1.0     NaN     NaN  1.080493  NaN -0.000021    -0.000004
# 2    1796     1.2     NaN     NaN  1.080501  NaN -0.000016    -0.000007
# 3    4019     1.4     NaN     NaN  1.080570  NaN  0.000015    -0.000002
# 4    2207     1.6     NaN     NaN  1.080521  NaN -0.000007    -0.000003
#
#    Middle_Band  Upper_Band  Lower_Band Signal
# 0          NaN         NaN         NaN   HOLD
# 1          NaN         NaN         NaN   HOLD
# 2          NaN         NaN         NaN   HOLD
# 3          NaN         NaN         NaN   HOLD
# 4          NaN         NaN         NaN   HOLD

# %%
features = [
    "SMA_10",
    "SMA_20",
    "EMA_10",
    "RSI",
    "MACD",
    "Signal_Line",
    "Upper_Band",
    "Lower_Band"
]

X = forex_data[features]

# %%
y = forex_data["Signal"]

# %%
data = forex_data.dropna()

# %%
X = data[features]

y = data["Signal"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
predictions = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, predictions)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7938144329896907

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          BUY       0.85      0.77      0.81        30
#         HOLD       0.80      0.84      0.82        44
#         SELL       0.71      0.74      0.72        23
#
#     accuracy                           0.79        97
#    macro avg       0.79      0.78      0.78        97
# weighted avg       0.80      0.79      0.79        97

# %%
cm = confusion_matrix(y_test, predictions)

print(cm)
# Out:
# [[23  4  3]
#  [ 3 37  4]
#  [ 1  5 17]]

# %%
importance = pd.DataFrame({
    "Feature": features,
    "Importance": model.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

print(importance)
# Out:
#        Feature  Importance
# 3          RSI    0.300156
# 4         MACD    0.123613
# 5  Signal_Line    0.119345
# 1       SMA_20    0.098452
# 6   Upper_Band    0.097523
# 0       SMA_10    0.093228
# 2       EMA_10    0.089873
# 7   Lower_Band    0.077809

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

plt.bar(
    importance["Feature"],
    importance["Importance"]
)

plt.title("Feature Importance")

plt.xticks(rotation=45)

plt.tight_layout()

plt.show()

# %%
data.to_csv(
    "Machine_Learning_Output/ml_dataset.csv",
    index=False
)

# %%
import os

print(os.listdir("Machine_Learning_Output"))
# Out:
# ['ml_dataset.csv']
